# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
percentages = [0,10,20,30,40,50,60,70]
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"],
    'font.size': 15})
results_path = '/nas/home/lcomanducci/xai_src_loc/endtoend_src_loc2/results_perturbation'

# %%
model_name = 'loc_cnn' # sample_cnn
figsize=(3,1.5)

# %%
2126355
# Out:
# 2126355

# %%
SNR=20
T60=0.3
results_split_path = os.path.join(results_path, model_name+'_FULL')
MAE_relevance2 = np.load(os.path.join(results_split_path,'relevance_FULL.npy'))
MAE_random2 = np.load(os.path.join(results_split_path,'random_FULL.npy'))
MAE_energy2 = np.load(os.path.join(results_split_path,'energy_FULL.npy'))
plt.figure(figsize=figsize)
plt.plot(percentages, MAE_relevance2,'k-o')
plt.plot(percentages, MAE_random2,'k--o')
plt.plot(percentages, MAE_energy2,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
plt.savefig('/nas/home/lcomanducci/xai_src_loc/endtoend_src_loc2/plots_spl/manipulation_SNR_FULL_'+model_name+'_.pdf',bbox_inches='tight')
#plt.legend(['$\mathrm{LRP}$','$\mathrm{Random}$','$\mathrm{Absolute}$'],fontsize=10)
plt.show()

# %% [markdown]
# # T60: 0.15 s SNR: 25 dB

# %%
SNR=25
T60=0.15
results_split_path = os.path.join(results_path, model_name+'_SNR_' + str(SNR) + '_T60_' + str(T60))
MAE_relevance1 = np.load(os.path.join(results_split_path,'relevance.npy'))
MAE_random1 = np.load(os.path.join(results_split_path,'random.npy'))
MAE_energy1 = np.load(os.path.join(results_split_path,'energy.npy'))
plt.figure(figsize=figsize)
plt.plot(percentages, MAE_relevance1,'k-o')
plt.plot(percentages, MAE_random1,'k--o')
plt.plot(percentages, MAE_energy1,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
#plt.legend(['$\mathrm{LRP}$','$\mathrm{Random}$','$\mathrm{Absolute}$'],fontsize=10)
plt.savefig('/nas/home/lcomanducci/xai_src_loc/endtoend_src_loc2/plots_spl/manipulation_SNR_' + str(SNR) + '_T60_' + str(T60)+'_'+model_name+'_.pdf',bbox_inches='tight')

plt.show()
print(MAE_relevance)
# Out:
# [0.11145265 0.15085163 0.15767171 0.1608184  0.16284225 0.1633223
#  0.16342015 0.16393794]

# %% [markdown]
# # T60: 0.3 s SNR: 20 dB

# %%
SNR=20
T60=0.3
results_split_path = os.path.join(results_path, model_name+'_SNR_' + str(SNR) + '_T60_' + str(T60))
MAE_relevance2 = np.load(os.path.join(results_split_path,'relevance.npy'))
MAE_random2 = np.load(os.path.join(results_split_path,'random.npy'))
MAE_energy2 = np.load(os.path.join(results_split_path,'energy.npy'))
plt.figure(figsize=figsize)
plt.plot(percentages, MAE_relevance2,'k-o')
plt.plot(percentages, MAE_random2,'k--o')
plt.plot(percentages, MAE_energy2,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
plt.savefig('/nas/home/lcomanducci/xai_src_loc/endtoend_src_loc2/plots_spl/manipulation_SNR_' + str(SNR) + '_T60_' + str(T60)+'_'+model_name+'_.pdf',bbox_inches='tight')
#plt.legend(['$\mathrm{LRP}$','$\mathrm{Random}$','$\mathrm{Absolute}$'],fontsize=10)
plt.show()

# %% [markdown]
# # T60: 0.4 s SNR: 15 dB

# %%
SNR=15
T60=0.4
results_split_path = os.path.join(results_path, model_name+'_SNR_' + str(SNR) + '_T60_' + str(T60))
MAE_relevance3 = np.load(os.path.join(results_split_path,'relevance.npy'))
MAE_random3 = np.load(os.path.join(results_split_path,'random.npy'))
MAE_energy3 = np.load(os.path.join(results_split_path,'energy.npy'))
plt.figure(figsize=figsize)
plt.plot(percentages, MAE_relevance3,'k-o')
plt.plot(percentages, MAE_random3,'k--o')
plt.plot(percentages, MAE_energy3,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
#plt.legend(['$\mathrm{LRP}$','$\mathrm{Random}$','$\mathrm{Absolute}$'],fontsize=10)
plt.savefig('/nas/home/lcomanducci/xai_src_loc/endtoend_src_loc2/plots_spl/manipulation_SNR_' + str(SNR) + '_T60_' + str(T60)+'_'+model_name+'_.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# # T60: 0.6 s SNR: 10 dB

# %%
SNR=10
T60=0.6
results_split_path = os.path.join(results_path, model_name+'_SNR_' + str(SNR) + '_T60_' + str(T60))
MAE_relevance4 = np.load(os.path.join(results_split_path,'relevance.npy'))
MAE_random4 = np.load(os.path.join(results_split_path,'random.npy'))
MAE_energy4 = np.load(os.path.join(results_split_path,'energy.npy'))
plt.figure(figsize=figsize)
plt.plot(percentages, MAE_relevance4,'k-o')
plt.plot(percentages, MAE_random4,'k--o')
plt.plot(percentages, MAE_energy4,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
#plt.legend(['$\mathrm{LRP}$','$\mathrm{Random}$','$\mathrm{Absolute}$'],fontsize=10)
plt.savefig('/nas/home/lcomanducci/xai_src_loc/endtoend_src_loc2/plots_spl/manipulation_SNR_' + str(SNR) + '_T60_' + str(T60)+'_'+model_name+'_.pdf',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(20,3))
plt.subplot(1,4,1)
plt.plot(percentages, MAE_relevance1,'k-o')
plt.plot(percentages, MAE_random1,'k--o')
plt.plot(percentages, MAE_energy1,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
plt.title('$SNR=10~\mathrm{dB}~T60=0.6 s$')

plt.subplot(1,4,2)
plt.plot(percentages, MAE_relevance2,'k-o')
plt.plot(percentages, MAE_random2,'k--o')
plt.plot(percentages, MAE_energy2,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
plt.title('$SNR=10~\mathrm{dB}~T60=0.6 s$')

plt.subplot(1,4,3)
plt.plot(percentages, MAE_relevance3,'k-o')
plt.plot(percentages, MAE_random3,'k--o')
plt.plot(percentages, MAE_energy3,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
plt.title('$SNR=10~\mathrm{dB}~T60=0.6 s$')

plt.subplot(1,4,4)
plt.plot(percentages, MAE_relevance4,'k-o')
plt.plot(percentages, MAE_random4,'k--o')
plt.plot(percentages, MAE_energy4,'k:o')
plt.xlabel('$P_{\%} [\%]$')
plt.ylabel('$\mathrm{MAE} [\mathrm{m}]$')
plt.title('$SNR=10~\mathrm{dB}~T60=0.6 s$')
plt.tight_layout()
#plt.savefig('/nas/home/lcomanducci/xai_src_loc/endtoend_src_loc2/plots_pages/manipulation__'+model_name+'_.png',bbox_inches='tight')
